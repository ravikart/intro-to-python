# %%
class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]
       
    
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
        
        
    def removeEdge(self, v1, v2):
        if self.containEdge(v1, v2) is False:
            return
        self.adjMatrix[v1][v2] = 0
        self.adjMatrix[v2][v1] = 0
        
        
    def containsEdge(self, v1, v2):
        return True if self.adjMatrix[v1][v2] > 0 else False
        
    def __str__(self):
        return str(self.adjMatrix)
    
    def __dfsHelper(self, source,destination,visited,path):
        
        if(self.adjMatrix[source][destination] > 0):
                path.append(destination)
                path.append(source)
                return True
            
        visited[source] = True
        for i in range(self.nVertices):
            if self.adjMatrix[source][i] > 0 and visited[i] is False:
                 if (self.__dfsHelper(i,destination,visited,path) is True):
                        path.append(source)
                        return True
                
        return False
        
    
    def dfs(self,source,destination):
        path = list()
        visited = [False for i in range(self.nVertices)]
        self.__dfsHelper(source, destination, visited,path)        
        return path        
                
                
veData = [int(i) for i in input().split()]
g = Graph(veData[0])
for i in range(veData[1]):
    datalist = [int(j) for j in input().split()]
    g.addEdge(datalist[0],datalist[1])
    
vertexSource = [int(i) for i in input().split()]
value = g.dfs(vertexSource[0],vertexSource[1])
print(*value)
# Out:
# 6 6
# 0 1
# 0 2
# 1 2
# 4 5
# 5 3
# 4 3
# 0 4

# %%
class Graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]
       
    
    def addEdge(self, v1, v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1
        
        
    def removeEdge(self, v1, v2):
        if self.containEdge(v1, v2) is False:
            return
        self.adjMatrix[v1][v2] = 0
        self.adjMatrix[v2][v1] = 0
        
        
    def containsEdge(self, v1, v2):
        return True if self.adjMatrix[v1][v2] > 0 else False
        
    def __str__(self):
        return str(self.adjMatrix)
    
    def __dfsHelper(self, source,destination,visited,path):
        visited[source] = True
        path.append(source)
        
        if source == destination:
            return True

        for i in range(self.nVertices):
            if self.adjMatrix[source][i] > 0 and visited[i] is False:
                temp = self.__dfsHelper(i,destination,visited,path)
                if temp:
                    return path
                
        path.pop()
        return False
        
    
    def dfs(self,source,destination):
        path = list()
        visited = [False for i in range(self.nVertices)]
        value = self.__dfsHelper(source, destination, visited,path)   
        if value is False:
            pass
        else:
            for i in path[::-1]:
                print(i,end=" ")
        return path        
                
                
veData = [int(i) for i in input().split()]
g = Graph(veData[0])
for i in range(veData[1]):
    datalist = [int(j) for j in input().split()]
    g.addEdge(datalist[0],datalist[1])
    
vertexSource = [int(i) for i in input().split()]
g.dfs(vertexSource[0],vertexSource[1])
# Out:
# 9 9
# 0 8
# 1 6
# 1 7
# 1 8
# 5 8
# 6 0
# 7 3
# 7 4
# 8 7
# 2 8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8fadf6af32f7> in <module>
#      59
#      60 vertexSource = [int(i) for i in input().split()]
# ---> 61 g.dfs(vertexSource[0],vertexSource[1])
#
# <ipython-input-1-8fadf6af32f7> in dfs(self, source, destination)
#      43         path = list()
#      44         visited = [False for i in range(self.nVertices)]
# ---> 45         value = self.__dfsHelper(source, destination, visited,path)
#      46         if value is False:
#      47             pass
#
# <ipython-input-1-8fadf6af32f7> in __dfsHelper(self, source, destination, visited, path)
#      36                     return path
#      37
# ---> 38         lst.pop()
#      39         return False
#      40
#
# NameError: name 'lst' is not defined
